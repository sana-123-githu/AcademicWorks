# %% [markdown]
# <a href="https://colab.research.google.com/github/sana-123-githu/AcademicWorks/blob/main/pgm3(pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Program to generate series of dates**

# %%
import pandas as pd
sr=pd.Series(pd.date_range('2021-05-01','2021-05-12',freq='D'))
print(sr.to_string(index=False))
# Out:
# 2021-05-01
# 2021-05-02
# 2021-05-03
# 2021-05-04
# 2021-05-05
# 2021-05-06
# 2021-05-07
# 2021-05-08
# 2021-05-09
# 2021-05-10
# 2021-05-11
# 2021-05-12

# %% [markdown]
# **Program to convert index to default**

# %%
import pandas as pd
data={'Name':['Sana','Cenna','Riza','Chrisa'],
      'Age':[22,21,34,13],
      'Rank':[1,2,3,4]}
index=['a1','a2','b1','b2']
df=pd.DataFrame(data,index)
print(df.to_string())
df.reset_index(inplace=True,drop=True)
print(df.to_string())
# Out:
#       Name  Age  Rank
# a1    Sana   22     1
# a2   Cenna   21     2
# b1    Riza   34     3
# b2  Chrisa   13     4
#      Name  Age  Rank
# 0    Sana   22     1
# 1   Cenna   21     2
# 2    Riza   34     3
# 3  Chrisa   13     4

# %% [markdown]
# **Program to find avg salary per occupation**

# %%
import pandas as pd
details={'Name':['Sana','Cenna','Riza','Chrisa'],
         'Occupation':['Engineer','Doctor','Engineer','Doctor'],
         'Salary':[25000,30000,15000,40000],}
data=pd.DataFrame(details)
print(data)
occ_average_salary=data.groupby('Occupation')['Salary'].mean()
print("Average Salary per Occupation:")
print(occ_average_salary)
# Out:
#      Name Occupation  Salary
# 0    Sana   Engineer   25000
# 1   Cenna     Doctor   30000
# 2    Riza   Engineer   15000
# 3  Chrisa     Doctor   40000
# Average Salary per Occupation:
# Occupation
# Doctor      35000.0
# Engineer    20000.0
# Name: Salary, dtype: float64
